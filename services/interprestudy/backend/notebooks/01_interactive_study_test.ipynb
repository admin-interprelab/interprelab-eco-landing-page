# %% [markdown]
# # InterpreStudy Content Generation Test
#
# Testing LangChain generators for Quizzes and Mnemonics.

# %%
import sys
import os
from dotenv import load_dotenv

# Add app to path
sys.path.append(os.path.abspath(".."))

# Load env
load_dotenv("../.env")

from app.llm.generators import generate_quiz, generate_mnemonic

# %% [markdown]
# ## Test Quiz Generation

# %%
topic = "Cardiology"
# quiz = await generate_quiz(topic, difficulty="intermediate", count=3)
# print(quiz.json(indent=2))

# %% [markdown]
# ## Test Mnemonic Generation

# %%
term = "Bradycardia"
# insight = await generate_mnemonic(term)
# print(insight.json(indent=2))
